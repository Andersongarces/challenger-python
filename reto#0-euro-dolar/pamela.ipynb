# %%
euro = float(input("ingrese el valor en euros: Є "))

def convertir(euro):

    return euro * 1.05550

cambio_a_dolar = float(convertir(euro))

print(f"El valor en dolar es: $ {cambio_a_dolar:.2f}")
# Out:
# ingrese el valor en euros: Є 2
# El valor en dolar es: $ 2.11
